# %%
import seaborn as sns
import pandas

sns.set_theme()

csv_file = pandas.read_csv('data.csv')

sns.relplot(data=csv_file, x='km', y='price')
sns.lmplot(data=csv_file, x='km', y='price')

def get_price_per_km(km):
    print("km: ", km, " | estimated price: ", (km * 0.05) + 0)

print(csv_file)

get_price_per_km(176000)
# Out:
#         km  price
# 0   240000   3650
# 1   139800   3800
# 2   150500   4400
# 3   185530   4450
# 4   176000   5250
# 5   114800   5350
# 6   166800   5800
# 7    89000   5990
# 8   144500   5999
# 9    84000   6200
# 10   82029   6390
# 11   63060   6390
# 12   74000   6600
# 13   97500   6800
# 14   67000   6800
# 15   76025   6900
# 16   48235   6900
# 17   93000   6990
# 18   60949   7490
# 19   65674   7555
# 20   54000   7990
# 21   68500   7990
# 22   22899   7990
# 23   61789   8290
# km:  176000  | estimated price:  8800.0
